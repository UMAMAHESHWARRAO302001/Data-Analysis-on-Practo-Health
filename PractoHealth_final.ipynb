# %%
import requests

# %%
URL="https://www.practo.com/search/doctors?results_type=doctor&q=%5B%7B%22word%22%3A%22Dentist%22%2C%22autocompleted%22%3Atrue%2C%22category%22%3A%22subspeciality%22%7D%5D&city=Hyderabad"

# %%
request_header={'User-Agent':'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/119.0.0.0 Safari/537.36'}

# %%
response=requests.get(URL,request_header)

# %%
response.status_code
# Out:
# 200

# %%
from bs4 import BeautifulSoup

# %%
soup=BeautifulSoup(response.text)

# %%
soup.prettify
# Out:
# <bound method Tag.prettify of <!DOCTYPE html>
# <html lang="en"><head><title>Best Dentists In Hyderabad - Instant Appointment Booking, View Fees, Feedbacks | Practo</title><meta content="Best Dentists in Hyderabad. Book Doctor's Appointment Online, View Fees, User feedbacks, Address &amp; Phone Numbers of Dentists in Hyderabad | Practo" name="description"/><meta charset="utf-8"/><meta content="ie=edge" http-equiv="x-ua-compatible"/><script nonce="kxBF27KolwboSL9KPr1eYgOkcif5gkQX" type="text/javascript">(function(w,d,s,l,i){w[l]=w[l]||[];w[l].push({'gtm.start':
#                       new Date().getTime(),event:'gtm.js'});var f=d.getElementsByTagName(s)[0],
#                       j=d.createElement(s),dl=l!='dataLayer'?'&l='+l:'';j.async=true;j.src=
#                       'https://www.googletagmanager.com/gtm.js?id='+i+dl;f.parentNode.insertBefore(j,f);
# ...

# %%
nae=soup.find('div',attrs={'data-qa-id':'doctor_experience'})

# %%
nae.text
# Out:
# '26\xa0years experience overall'

# %%
twitters=soup.find_all('div',attrs={'class':'listing-doctor-card'})

# %%
for twit in twitters:
    print(twit.text)
# Out:
# View ProfileDr. Chaitanya Kumar ReddyDentist26 years experience overallKhajaguda,Hyderabad  GC Dental World₹500 Consultation fee at clinic98% 259 Patient Stories
# View ProfileDr. PreetiDentist15 years experience overallKondapur,Hyderabad  Elysian  Aesthetics Dental Care₹150 Consultation fee at clinic94% 7 Patient Stories
# View ProfileDr. Anil KumarDentist20 years experience overallKondapur,Hyderabad  Elysian  Aesthetics Dental Care + 1 more₹150 Consultation fee at clinic98% 135 Patient Stories
# View ProfileDr. HariniDentist22 years experience overallWest Marredpally,Hyderabad  Esthetix Dental  + 1 more₹400 Consultation fee at clinic100% 43 Patient Stories
# View ProfileDr. Chandrashekhar ReddyDentist24 years experience overallChanda Nagar,Hyderabad  Sri Sai Dental Hospital₹400 Consultation fee at clinic95% 11 Patient Stories
# ...

# %%
name =soup.find('h2',attrs={'class':'doctor_name'})

# %%
name.text
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_15180/2149843946.py in <module>
# ----> 1 name.text
#
# AttributeError: 'NoneType' object has no attribute 'text'

# %%
import pandas as pd
import numpy as np

# %%
name=[]
specialist=[]
place=[]
hosiptal=[]
consult_fee=[]
recommendation=[]
reviews=[]

        names=container.find('div',attrs={'class':'u-color--primary uv2-spacer--xs-bottom'})
        if names is None:
            name.append(np.NaN)
        else:
            name.append(names.text)

        desgination=container.find('div',attrs={'class':'u-grey_3-text'})
        if desgination is None:
            specialist.append(np.NaN)
        else:
            specialist.append(desgination.text)
        places=container.find('div',attrs={'class':'u-bold u-d-inlineblock u-valign--middle'})
        if places is None:
            place.append(np.NaN)
        else:
            place.append(places.text)
            
        clinic=container.find('span',attrs={'class':'u-c-pointer u-t-hover-underline'})
        if clinic is None:
            hosiptal.append(np.NaN)
        else:
            hosiptal.append(clinic.text)
            
        fee=container.find('span',attrs={'data-qa-id':'consultation_fee'})
        if fee is None:
            consult_fee.append(np.NaN)
        else:
            consult_fee.append(fee.text)
        
        recommend=container.find('span',attrs={'data-qa-id':'doctor_recommendation'})
        if recommend is None:
            recommendation.append(np.NaN)
        else:
            recommendation.append(recommend.text)
        review=container.find('span',attrs={'data-qa-id':'total_feedback'})
        for rev in review:
            a=(rev.text.split(r"\x")[0][:])
            
            if a is None:
                reviews.append(np.NaN)
            else:
                reviews.append(review.text)
# Out:
#   File "C:\Users\dell\AppData\Local\Temp/ipykernel_15180/1773594110.py", line 9
#     names=container.find('div',attrs={'class':'u-color--primary uv2-spacer--xs-bottom'})
#     ^
# IndentationError: unexpected indent

# %%
hosiptal=[]
consult_fees=[]
recommendation=[]

# %%
pages=36
for i in range(1,pages):
    URL=f"https://www.practo.com/search/doctors?results_type=doctor&q=%5B%7B%22word%22%3A%22Dentist%22%2C%22autocompleted%22%3Atrue%2C%22category%22%3A%22subspeciality%22%7D%5D&city=Hyderabad&page={i}"
    request_header={'content-type': 'text/plain',
                    'User-Agent': "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/119.0.0.0 Safari/537.36",
                    'Accept-Encoding': 'gzip, deflate, br'}
    response = requests.get(URL,headers=request_header)
    html_code = response.text
    soup = BeautifulSoup(html_code)
    containers = soup.find_all('div',attrs={'class':'listing-doctor-card'})
    for container in containers:
        clinic=container.find('span',attrs={'class':'u-c-pointer u-t-hover-underline'})
        if clinic is None:
            hosiptal.append(np.NaN)
        else:
            hosiptal.append(clinic.text)
            
        fees=container.find('span',attrs={'data-qa-id':'consultation_fee'})
        for fee in fees:
            a=(fee.text.split("₹")[0:])
            if a is None:
                consult_fees.append(np.NaN)
            else:
                consult_fees.append(a)
        
        recommend=container.find('span',attrs={'data-qa-id':'doctor_recommendation'})
        if recommend is None:
            recommendation.append(np.NaN)
        else:
            recommendation.append(recommend.text)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_15180/3191304831.py in <module>
#       5                     'User-Agent': "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/119.0.0.0 Safari/537.36",
#       6                     'Accept-Encoding': 'gzip, deflate, br'}
# ----> 7     response = requests.get(URL,headers=request_header)
#       8     html_code = response.text
#       9     soup = BeautifulSoup(html_code)
#
# ~\anaconda3\lib\site-packages\requests\api.py in get(url, params, **kwargs)
#      73     """
#      74
# ---> 75     return request('get', url, params=params, **kwargs)
#      76
#      77
#
# ~\anaconda3\lib\site-packages\requests\api.py in request(method, url, **kwargs)
#      59     # cases, and look like a memory leak in others.
#      60     with sessions.Session() as session:
# ...

# %%
len(hosiptal)

# %%
consult_fees
# Out:
# ['',
#  '',
#  ['', ''],
#  [''],
#  ['500'],
#  ['', ''],
#  [''],
#  ['150'],
#  ['', ''],
#  [''],
#  ['150'],
#  ['', ''],
#  [''],
#  ['400'],
#  ['', ''],
#  [''],
#  ['300'],
#  ['', ''],
#  [''],
#  ['400'],
#  ['', ''],
#  [''],
#  ['200'],
#  ['', ''],
#  [''],
#  ['500'],
#  ['', ''],
#  [''],
#  ['500'],
#  ['', ''],
#  [''],
#  ['300'],
#  ['', ''],
#  [''],
#  ['350'],
#  ['', ''],
#  [''],
#  ['300'],
#  ['', ''],
#  [''],
#  ['500'],
#  ['', ''],
#  [''],
#  ['200'],
#  ['', ''],
#  [''],
#  ['500'],
#  ['', ''],
#  [''],
#  ['300'],
#  ['', ''],
#  [''],
#  ['300'],
#  ['', ''],
#  [''],
#  ['250'],
#  ['', ''],
#  [''],
#  ['300'],
#  ['', ''],
#  [''],
#  ['400'],
#  ['', ''],
#  [''],
#  ['300'],
#  ['', ''],
#  [''],
#  ['400'],
#  ['', ''],
#  [''],
#  ['300'],
#  ['', ''],
#  [''],
#  ['400'],
#  ['', ''],
#  [''],
#  ['300'],
#  ['', ''],
#  [''],
#  ['300'],
#  ['', ''],
#  [''],
#  ['1000'],
#  ['', ''],
#  [''],
#  ['500'],
#  ['', ''],
#  [''],
# ...

# %%
len(recommendation)
# Out:
# 350

# %%
len(name)
# Out:
# 350

# %%
len(specialist)
# Out:
# 350

# %%
place=soup.find('div',attrs={'class':'u-bold u-d-inlineblock u-valign--middle'})

# %%
place.text
# Out:
# 'Nallagandla,Hyderabad'

# %%
len(place)
# Out:
# 350

# %%
price=soup.find('div',attrs={'class':'uv2-spacer--xs-top'})

# %%
price.text
# Out:
# '10\xa0years experience overall'

# %%
clinic=soup.find('span',attrs={'class':'u-c-pointer u-t-hover-underline'})

# %%
clinic.text
# Out:
# 'Partha Dental  Skin Hair'

# %%
len(hosiptal)
# Out:
# 350

# %%
fee=soup.find('span',attrs={'data-qa-id':'consultation_fee'})

# %%
fee.text
# Out:
# '₹500'

# %%
len(consult_fee)
# Out:
# 350

# %%
recommend=soup.find('span',attrs={'data-qa-id':'doctor_recommendation'})

# %%
recommend.text
# Out:
# '100% '

# %%
len(recommendation)
# Out:
# 350

# %%
review=soup.find('span',attrs={'data-qa-id':'total_feedback'})

# %%
review.text
# Out:
# '2\xa0Patient Stories'

# %%
len(reviews)
# Out:
# 350

# %%
docter_names=[]
specialist=[]
place=[]
hosiptal=[]
consult_fee=[]
recommendation=[]
reviews=[]

# %%
specialist
# Out:
# ['Dentist26\xa0years experience overall',
#  'Dentist20\xa0years experience overall',
#  'Dentist15\xa0years experience overall',
#  'Dentist22\xa0years experience overall',
#  'Dentist23\xa0years experience overall',
#  'Dentist24\xa0years experience overall',
#  'Dentist9\xa0years experience overall',
#  'Dentist25\xa0years experience overall',
#  'Dentist21\xa0years experience overall',
#  'Dentist19\xa0years experience overall',
#  'Dentist21\xa0years experience overall',
#  'Dentist18\xa0years experience overall',
#  'Dentist22\xa0years experience overall',
#  'Dentist22\xa0years experience overall',
#  'Dentist11\xa0years experience overall',
#  'Dentist18\xa0years experience overall',
#  'Dentist13\xa0years experience overall',
#  'Dentist7\xa0years experience overall',
#  'Dentist14\xa0years experience overall',
#  'Dentist16\xa0years experience overall',
#  'Dentist18\xa0years experience overall',
#  'Dentist13\xa0years experience overall',
# ...

# %%
place
# Out:
# ['Khajaguda,Hyderabad',
#  'Kondapur,Hyderabad',
#  'Kondapur,Hyderabad',
#  'West Marredpally,Hyderabad',
#  'Kondapur,Hyderabad',
#  'Chanda Nagar,Hyderabad',
#  'SR Nagar,Hyderabad',
#  'Banjara Hills,Hyderabad',
#  'Gachibowli,Hyderabad',
#  'Malkajgiri,Hyderabad',
#  'Banjara Hills,Hyderabad',
#  'Manikonda,Hyderabad',
#  'Banjara Hills,Hyderabad',
#  'Madinaguda,Hyderabad',
#  'Chintal,Hyderabad',
#  'KPHB,Hyderabad',
#  'Kukatpally,Hyderabad',
#  'Kondapur,Hyderabad',
#  'Kondapur,Hyderabad',
#  'Domalguda,Hyderabad',
#  'Nallakunta,Hyderabad',
#  'Kukatpally,Hyderabad',
#  'Kukatpally,Hyderabad',
#  'Madhapur,Hyderabad',
#  'KPHB,Hyderabad',
#  'Nallagandla,Hyderabad',
#  'Karkhana,Hyderabad',
#  'Chanda Nagar,Hyderabad',
#  'Vanasthalipuram,Hyderabad',
#  'Tarnaka,Hyderabad',
#  'Jubilee Hills,Hyderabad',
#  'Nizampet,Hyderabad',
#  'Banjara Hills,Hyderabad',
#  'Kukatpally,Hyderabad',
#  'Tarnaka,Hyderabad',
#  'BHEL,Hyderabad',
#  'Nanakramguda,Hyderabad',
# ...

# %%
hosiptal
# Out:
# ['GC Dental World',
#  'Elysian  Aesthetics Dental Care',
#  'Elysian  Aesthetics Dental Care',
#  'Esthetix Dental ',
#  'Dental 360',
#  'Sri Sai Dental Hospital',
#  'GB Dental Hospital',
#  'Dr.Gowds Dental Hospitals',
#  'Focus Dental Care',
#  'Anandbagh Super Speciality Dental Hospital',
#  'The Dental Specialists',
#  'Clips & Implants Dental Studio',
#  'Vistadent Dental Clinic',
#  "Kishore's Dental Clinic",
#  'Harsha Dental - Dantam',
#  'LN Dental',
#  "Dr. Mohan's Dental Care",
#  'Ekadanta Dental Care',
#  'Urban Dental Wellness',
#  'Anita Krishna Dental Clinic',
#  'Viva Smilez Dental Hospital',
#  'Ethos Dental',
#  'Danta Vaidhya - The Dental Studio',
#  'Dr. Lavanya Dental & Implant Centre',
#  'MK Dental',
#  'Mulberry Super Speciality Dental and Gynecology',
#  'Pearly Teeth Superspeciality Dental Hospital',
#  'ISHAA SKIN AND HAIR AND KRUTIKA DENTAL CLINIC',
#  'Prashanth Dental world class Dental centre',
#  'Tarnaka Dental Clinic',
# ...

# %%
consult_fee
# Out:
# ['₹500',
#  '₹150',
#  '₹150',
#  '₹400',
#  '₹300',
#  '₹400',
#  '₹200',
#  '₹500',
#  '₹500',
#  '₹300',
#  '₹350',
#  '₹300',
#  '₹500',
#  '₹500',
#  '₹200',
#  '₹300',
#  '₹300',
#  '₹250',
#  '₹300',
#  '₹400',
#  '₹300',
#  '₹400',
#  '₹300',
#  '₹400',
#  '₹300',
#  '₹300',
#  '₹1000',
#  '₹500',
#  '₹500',
#  '₹300',
#  '₹250',
#  '₹500',
#  '₹300',
#  '₹400',
#  '₹300',
#  '₹300',
#  '₹500',
#  '₹300',
#  '₹300',
#  '₹300',
#  '₹400',
#  '₹300',
#  '₹300',
#  '₹300',
#  '₹300',
#  '₹500',
#  '₹450',
#  '₹500',
#  '₹500',
#  '₹400',
#  '₹400',
#  '₹500',
#  '₹300',
#  '₹300',
#  '₹300',
#  '₹500',
#  '₹300',
#  '₹200',
#  '₹300',
#  '₹200',
#  '₹300',
#  '₹500',
#  '₹300',
#  '₹1000',
#  '₹400',
#  '₹500',
#  '₹200',
#  '₹300',
#  '₹300',
#  '₹500',
#  '₹200',
#  '₹300',
#  '₹500',
#  '₹300',
#  '₹300',
#  '₹200',
#  '₹500',
#  '₹300',
#  '₹500',
#  '₹400',
#  '₹300',
#  '₹300',
#  '₹300',
#  '₹300',
#  '₹500',
#  '₹300',
#  '₹500',
#  '₹350',
#  '₹500',
#  '₹350',
# ...

# %%
recommendation
# Out:
# []

# %%
reviews
# Out:
# ['259\xa0Patient Stories',
#  '135\xa0Patient Stories',
#  '7\xa0Patient Stories',
#  '43\xa0Patient Stories',
#  '276\xa0Patient Stories',
#  '11\xa0Patient Stories',
#  '109\xa0Patient Stories',
#  '52\xa0Patient Stories',
#  '115\xa0Patient Stories',
#  '41\xa0Patient Stories',
#  '300\xa0Patient Stories',
#  '48\xa0Patient Stories',
#  '31\xa0Patient Stories',
#  '54\xa0Patient Stories',
#  '1173\xa0Patient Stories',
#  '52\xa0Patient Stories',
#  '54\xa0Patient Stories',
#  '264\xa0Patient Stories',
#  '31\xa0Patient Stories',
#  '63\xa0Patient Stories',
#  '161\xa0Patient Stories',
#  '101\xa0Patient Stories',
#  '143\xa0Patient Stories',
#  '97\xa0Patient Stories',
#  '42\xa0Patient Stories',
#  '18\xa0Patient Stories',
#  '8\xa0Patient Stories',
#  '34\xa0Patient Stories',
#  '3\xa0Patient Stories',
#  '26\xa0Patient Stories',
#  '36\xa0Patient Stories',
#  '116\xa0Patient Stories',
#  '16\xa0Patient Stories',
#  nan,
#  '8\xa0Patient Stories',
#  '17\xa0Patient Stories',
# ...

# %% [markdown]
# # Final Code

# %%
docter_names=[]
specialist_=[]
locality=[]
hosiptal_name=[]
Appointment_fee=[]
recommendations_=[]
reviews_=[]

# %%
len(docter_names)
# Out:
# 180

# %%
docter_names.pop()
# Out:
# 'Dr. K Sravani Reddy'

# %%
specialist_.pop()
# Out:
# 'Dentist12\xa0years experience overall'

# %%
len(specialist_)
# Out:
# 180

# %%
len(locality)
# Out:
# 180

# %%
len(hosiptal_name)
# Out:
# 180

# %%
locality.pop()
# Out:
# 'Karkhana,Hyderabad'

# %%
len(Appointment_fee)
# Out:
# 180

# %%
len(recommendations_)
# Out:
# 180

# %%
len(reviews_)
# Out:
# 180

# %%
df=pd.DataFrame({'Doctor':docter_names,
                "special":specialist_,
                "locality":locality,
                "hospital":hosiptal_name,
                "fee":Appointment_fee,
                "Recommend":recommendations_,
                "reviews":reviews_})

# %%
len(df[df['Doctor']=="Dr. B Varun Rao"].duplicated())
# Out:
# 11

# %%
df['special']=="Gastroenterologist18 years experience overall"
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 175    False
# 176    False
# 177    False
# 178    False
# 179    False
# Name: special, Length: 180, dtype: bool

# %%
df.head()
# Out:
#                   Doctor                                        special  \
# 0        Dr. B Varun Rao  Gastroenterologist18 years experience overall
# 1        Dr. B Varun Rao  Gastroenterologist18 years experience overall
# 2        Dr. B Varun Rao  Gastroenterologist18 years experience overall
# 3  Dr. Sudarshan Reddy K  Gastroenterologist16 years experience overall
# 4   Dr. Raghuram Kondala  Gastroenterologist18 years experience overall
#
#                 locality               hospital   fee Recommend  \
# 0  Hitech City,Hyderabad    Medicover Hospitals  ₹500      91%
# 1  Hitech City,Hyderabad    Medicover Hospitals  ₹600     100%
# 2  Hitech City,Hyderabad    Medicover Hospitals  ₹900      96%
# 3        Uppal,Hyderabad           Tx Hospitals  ₹800      97%
# 4   Gachibowli,Hyderabad  Continental Hospitals  ₹500      90%
#
#               reviews
# 0  93 Patient Stories
# 1                 NaN
# 2  65 Patient Stories
# 3  18 Patient Stories
# 4  10 Patient Stories

# %%
docter_names=[]
specialist_=[]
locality=[]
hosiptal_name=[]
Appointment_fee=[]
recommendations_=[]
reviews_=[]

# %%
pages=38
for i in range(pages):
    URL=['https://www.practo.com/search/doctors?results_type=doctor&q=%5B%7B%22word%22%3A%22Dentist%22%2C%22autocompleted%22%3Atrue%2C%22category%22%3A%22subspeciality%22%7D%5D&city=Hyderabad&page={i}']
    

    request_header={'content-type': 'text/plain',
                    'User-Agent': "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/119.0.0.0 Safari/537.36",
                    'Accept-Encoding': 'gzip, deflate, br'}
    response = requests.get(url,headers=request_header)
    html_code=response.text
    soup=BeautifulSoup(html_code)
#response = requests.get(URL,headers=request_header)
#html_code = response.text
#soup = BeautifulSoup(html_code)
    containers = soup.find_all('div',attrs={'class':'info-section'})
    for container in containers:
        names=container.find('h2',attrs={'data-qa-id':'doctor_name'})
        if names is None:
            docter_names.append(np.NaN)
        else:
            docter_names.append(names.text)
                
        desgination=container.find('div',attrs={'class':'u-grey_3-text'})
        if desgination is None:
            specialist_.append(np.NaN)
        else:
            specialist_.append(desgination.text)
        places=container.find('div',attrs={'class':'u-bold u-d-inlineblock u-valign--middle'})
        if places is None:
            locality.append(np.NaN)
        else:
            locality.append(places.text)
            
        clinic=container.find('span',attrs={'class':'u-c-pointer u-t-hover-underline'})
        if clinic is None:
            hosiptal_name.append(np.NaN)
        else:
            hosiptal_name.append(clinic.text)
            
        fees=container.find('span',attrs={'data-qa-id':'consultation_fee'})
        if fees is None:
            Appointment_fee.append(np.NaN)
        else:
            Appointment_fee.append(fees.text)
        
        recommend=container.find('span',attrs={'data-qa-id':'doctor_recommendation'})
        if recommend is None:
            recommendations_.append(np.NaN)
        else:
            recommendations_.append(recommend.text)
        review=container.find('span',attrs={'data-qa-id':'total_feedback'})
        if review is None:
            reviews_.append(np.NaN)
        else:
            reviews_.append(review.text)

# %%
len(docter_names)
# Out:
# 380

# %%
len(specialist_)
# Out:
# 380

# %%
len(locality)
# Out:
# 380

# %%
len(hosiptal_name)
# Out:
# 380

# %%
len(Appointment_fee)
# Out:
# 380

# %%
len(recommendations_)
# Out:
# 380

# %%
len(reviews_)
# Out:
# 380

# %%
df=pd.DataFrame({'Doctor':docter_names,
                "special":specialist_,
                "locality":locality,
                "hospitalname":hosiptal_name,
                "fee":Appointment_fee,
                "recommendPercent":recommendations_,
                "reviews":reviews_})

# %%
df.head()
# Out:
#                       Doctor                             special  \
# 0  Dr. Chaitanya Kumar Reddy  Dentist26 years experience overall
# 1                 Dr. Preeti  Dentist15 years experience overall
# 2             Dr. Anil Kumar  Dentist20 years experience overall
# 3       Dr. S Sreedhar Reddy  Dentist24 years experience overall
# 4              Dr. M Sridhar  Dentist23 years experience overall
#
#                      locality                     hospitalname   fee  \
# 0         Khajaguda,Hyderabad                  GC Dental World  ₹500
# 1          Kondapur,Hyderabad  Elysian  Aesthetics Dental Care  ₹150
# 2          Kondapur,Hyderabad  Elysian  Aesthetics Dental Care  ₹150
# 3  West Marredpally,Hyderabad                 Esthetix Dental   ₹400
# 4          Kondapur,Hyderabad                       Dental 360  ₹300
#
#   recommendPercent              reviews
# 0             98%   259 Patient Stories
# 1             94%     7 Patient Stories
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 380 entries, 0 to 379
# Data columns (total 7 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Doctor            380 non-null    object
#  1   special           380 non-null    object
#  2   locality          380 non-null    object
#  3   hospitalname      380 non-null    object
#  4   fee               380 non-null    object
#  5   recommendPercent  380 non-null    object
#  6   reviews           380 non-null    object
# dtypes: object(7)
# memory usage: 20.9+ KB

# %%
df['Doctor'].value_counts()
# Out:
# Dr. Chaitanya Kumar Reddy    38
# Dr. Preeti                   38
# Dr. Anil Kumar               38
# Dr. S Sreedhar Reddy         38
# Dr. M Sridhar                38
# Dr. Chandrashekhar Reddy     38
# Dr. Adusumilli Gopinath      38
# Dr. Md Safiuddin Quraishi    38
# Dr. K Sravani Reddy          38
# Dr. Surendra Kumar Alluri    38
# Name: Doctor, dtype: int64

# %%
# Out:
# 2380

# %%
'https://www.practo.com/search/doctors?results_type=doctor&q=%5B%7B%22word%22%3A%22cardiologist%22%2C%22autocompleted%22%3Atrue%2C%22category%22%3A%22subspeciality%22%7D%5D&city=Hyderabad&page={i}',
        'https://www.practo.com/search/doctors?results_type=doctor&q=%5B%7B%22word%22%3A%22General%20Physician%22%2C%22autocompleted%22%3Atrue%2C%22category%22%3A%22subspeciality%22%7D%5D&city=Hyderabad&page={i}',
        'https://www.practo.com/search/doctors?results_type=doctor&q=%5B%7B%22word%22%3A%22Dermatologist%22%2C%22autocompleted%22%3Atrue%2C%22category%22%3A%22subspeciality%22%7D%5D&city=Hyderabad&page={i}',
        'https://www.practo.com/search/doctors?results_type=doctor&q=%5B%7B%22word%22%3A%22Ear-nose-throat%20(ent)%20Specialist%22%2C%22autocompleted%22%3Atrue%2C%22category%22%3A%22subspeciality%22%7D%5D&city=Hyderabad&page={i}',
        'https://www.practo.com/search/doctors?results_type=doctor&q=%5B%7B%22word%22%3A%22Gynecologist%2Fobstetrician%22%2C%22autocompleted%22%3Atrue%2C%22category%22%3A%22subspeciality%22%7D%5D&city=Hyderabad&page={i}'
        
        'https://www.practo.com/search/doctors?results_type=doctor&q=%5B%7B%22word%22%3A%22gastroenterologist%22%2C%22autocompleted%22%3Atrue%2C%22category%22%3A%22subspeciality%22%7D%5D&city=Hyderabad&page={i}

# %%
specialist_
# Out:
# ['Gastroenterologist18\xa0years experience overall',
#  'Gastroenterologist16\xa0years experience overall',
#  'Gastroenterologist18\xa0years experience overall',
#  'Gastroenterologist27\xa0years experience overall',
#  'Gastroenterologist14\xa0years experience overall',
#  'Gastroenterologist28\xa0years experience overall',
#  'Gastroenterologist27\xa0years experience overall',
#  'Gastroenterologist19\xa0years experience overall',
#  'Gastroenterologist23\xa0years experience overall',
#  'Gastroenterologist11\xa0years experience overall',
#  'Dentist26\xa0years experience overall',
#  'Dentist20\xa0years experience overall',
#  'Dentist15\xa0years experience overall',
#  'Dentist22\xa0years experience overall',
#  'Dentist23\xa0years experience overall',
#  'Dentist24\xa0years experience overall',
#  'Dentist9\xa0years experience overall',
#  'Dentist25\xa0years experience overall',
#  'Dentist21\xa0years experience overall',
#  'Dentist19\xa0years experience overall',
# ...

# %%
len(locality)
# Out:
# 2380

# %%
len(hosiptal_name)
# Out:
# 2380

# %%
len(Appointment_fee)
# Out:
# 2380

# %%
len(recommendations_)
# Out:
# 2380

# %%
len(reviews_)
# Out:
# 2380

# %%
assured=soup.find('div',attrs={'class':'c-profile--verification'})

# %%
assured.text
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_16012/1262323813.py in <module>
# ----> 1 assured.text
#
# AttributeError: 'NoneType' object has no attribute 'text'

# %%
reviews
# Out:
# ['259\xa0Patient Stories',
#  '135\xa0Patient Stories',
#  '7\xa0Patient Stories',
#  '43\xa0Patient Stories',
#  '276\xa0Patient Stories',
#  '11\xa0Patient Stories',
#  '109\xa0Patient Stories',
#  '52\xa0Patient Stories',
#  '115\xa0Patient Stories',
#  '41\xa0Patient Stories',
#  '300\xa0Patient Stories',
#  '48\xa0Patient Stories',
#  '31\xa0Patient Stories',
#  '54\xa0Patient Stories',
#  '1173\xa0Patient Stories',
#  '52\xa0Patient Stories',
#  '54\xa0Patient Stories',
#  '264\xa0Patient Stories',
#  '31\xa0Patient Stories',
#  '63\xa0Patient Stories',
#  '161\xa0Patient Stories',
#  '101\xa0Patient Stories',
#  '143\xa0Patient Stories',
#  '97\xa0Patient Stories',
#  '42\xa0Patient Stories',
#  '18\xa0Patient Stories',
#  '8\xa0Patient Stories',
#  '34\xa0Patient Stories',
#  '3\xa0Patient Stories',
#  '26\xa0Patient Stories',
#  '36\xa0Patient Stories',
#  '116\xa0Patient Stories',
#  '16\xa0Patient Stories',
#  nan,
#  '8\xa0Patient Stories',
#  '17\xa0Patient Stories',
# ...

# %%
specialist
# Out:
# ['Dentist26\xa0years experience overall',
#  'Dentist20\xa0years experience overall',
#  'Dentist15\xa0years experience overall',
#  'Dentist22\xa0years experience overall',
#  'Dentist23\xa0years experience overall',
#  'Dentist24\xa0years experience overall',
#  'Dentist9\xa0years experience overall',
#  'Dentist25\xa0years experience overall',
#  'Dentist21\xa0years experience overall',
#  'Dentist19\xa0years experience overall',
#  'Dentist21\xa0years experience overall',
#  'Dentist18\xa0years experience overall',
#  'Dentist22\xa0years experience overall',
#  'Dentist22\xa0years experience overall',
#  'Dentist11\xa0years experience overall',
#  'Dentist18\xa0years experience overall',
#  'Dentist13\xa0years experience overall',
#  'Dentist7\xa0years experience overall',
#  'Dentist14\xa0years experience overall',
#  'Dentist16\xa0years experience overall',
#  'Dentist18\xa0years experience overall',
#  'Dentist13\xa0years experience overall',
# ...

# %%
years=soup.find('div',attrs={'class':'u-bold'})

# %%
years.text
# Out:
# 'Nacharam,Hyderabad'

# %%
review=soup.find_all('span',attrs={'data-qa-id':'total_feedback'})
for rev in review:
    a=(rev.text.split(r"\x")[0][:])
    print(a)
# Out:
# 156 Patient Stories
# 95 Patient Stories
# 10 Patient Stories
# 11 Patient Stories
# 28 Patient Stories
# 1 Patient Story
# 147 Patient Stories
# 58 Patient Stories
# 31 Patient Stories

# %%
for rev
# Out:
#   File "C:\Users\dell\AppData\Local\Temp/ipykernel_16012/1120915301.py", line 1
#     for rev
#             ^
# SyntaxError: invalid syntax

# %%
fees=soup.find_all('span',attrs={'data-qa-id':'consultation_fee'})
for fe in fees:
    a=(fe.text.split("₹")[1])
    print(a)
# Out:
# 700
# 600
# 700
# 600
# 600
# 600
# 800
# 700
# 800
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_16012/1674868133.py in <module>
#       1 fees=soup.find_all('span',attrs={'data-qa-id':'consultation_fee'})
#       2 for fe in fees:
# ----> 3     a=(fe.text.split("₹")[1])
#       4     print(a)
#
# IndexError: list index out of range

# %%
years=soup.find('div',attrs={'class':'uv2-spacer--xs-top'})

# %%
years.text
# Out:
# '35\xa0years experience overall'

# %%
experi=[]

# %%
pages=35
for i in range(1,pages):
    URL=['https://www.practo.com/search/doctors?results_type=doctor&q=%5B%7B%22word%22%3A%22gastroenterologist%22%2C%22autocompleted%22%3Atrue%2C%22category%22%3A%22subspeciality%22%7D%5D&city=Hyderabad&page={i}',
        'https://www.practo.com/search/doctors?results_type=doctor&q=%5B%7B%22word%22%3A%22Dentist%22%2C%22autocompleted%22%3Atrue%2C%22category%22%3A%22subspeciality%22%7D%5D&city=Hyderabad&page={i}',
        'https://www.practo.com/search/doctors?results_type=doctor&q=%5B%7B%22word%22%3A%22cardiologist%22%2C%22autocompleted%22%3Atrue%2C%22category%22%3A%22subspeciality%22%7D%5D&city=Hyderabad&page={i}',
        'https://www.practo.com/search/doctors?results_type=doctor&q=%5B%7B%22word%22%3A%22General%20Physician%22%2C%22autocompleted%22%3Atrue%2C%22category%22%3A%22subspeciality%22%7D%5D&city=Hyderabad&page={i}',
        'https://www.practo.com/search/doctors?results_type=doctor&q=%5B%7B%22word%22%3A%22Dermatologist%22%2C%22autocompleted%22%3Atrue%2C%22category%22%3A%22subspeciality%22%7D%5D&city=Hyderabad&page={i}',
        'https://www.practo.com/search/doctors?results_type=doctor&q=%5B%7B%22word%22%3A%22Ear-nose-throat%20(ent)%20Specialist%22%2C%22autocompleted%22%3Atrue%2C%22category%22%3A%22subspeciality%22%7D%5D&city=Hyderabad&page={i}',
        'https://www.practo.com/search/doctors?results_type=doctor&q=%5B%7B%22word%22%3A%22Gynecologist%2Fobstetrician%22%2C%22autocompleted%22%3Atrue%2C%22category%22%3A%22subspeciality%22%7D%5D&city=Hyderabad&page={i}']

    request_header={'content-type': 'text/plain',
                    'User-Agent': "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/119.0.0.0 Safari/537.36",
                    'Accept-Encoding': 'gzip, deflate, br'}
    for url in URL:
        response = requests.get(url,headers=request_header)
        html_code=response.text
        soup=BeautifulSoup(html_code)
#response = requests.get(URL,headers=request_header)
#html_code = response.text
#soup = BeautifulSoup(html_code)
        containers = soup.find_all('div',attrs={'class':'listing-doctor-card'})
        for container in containers:
            experience=container.find('div',attrs={'class':'uv2-spacer--xs-top'})
            if experience is None:
                experi.append(np.NaN)
            else:
                experi.append(experience.text)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_17240/3258082923.py in <module>
#      13                     'Accept-Encoding': 'gzip, deflate, br'}
#      14     for url in URL:
# ---> 15         response = requests.get(url,headers=request_header)
#      16         html_code=response.text
#      17         soup=BeautifulSoup(html_code)
#
# ~\anaconda3\lib\site-packages\requests\api.py in get(url, params, **kwargs)
#      73     """
#      74
# ---> 75     return request('get', url, params=params, **kwargs)
#      76
#      77
#
# ~\anaconda3\lib\site-packages\requests\api.py in request(method, url, **kwargs)
#      59     # cases, and look like a memory leak in others.
#      60     with sessions.Session() as session:
# ---> 61         return session.request(method=method, url=url, **kwargs)
#      62
#      63
#
# ...

# %%
len(experi)
# Out:
# 2380

# %%
fee=soup.find('span',attrs={'data-qa-id':'consultation_fee'})

# %%
fee.text
# Out:
# '₹700'

# %%
Appointment_fee_=[]

# %%
pages=35
for i in range(1,pages):
    URL=['https://www.practo.com/search/doctors?results_type=doctor&q=%5B%7B%22word%22%3A%22gastroenterologist%22%2C%22autocompleted%22%3Atrue%2C%22category%22%3A%22subspeciality%22%7D%5D&city=Hyderabad&page={i}',
        'https://www.practo.com/search/doctors?results_type=doctor&q=%5B%7B%22word%22%3A%22Dentist%22%2C%22autocompleted%22%3Atrue%2C%22category%22%3A%22subspeciality%22%7D%5D&city=Hyderabad&page={i}',
        'https://www.practo.com/search/doctors?results_type=doctor&q=%5B%7B%22word%22%3A%22cardiologist%22%2C%22autocompleted%22%3Atrue%2C%22category%22%3A%22subspeciality%22%7D%5D&city=Hyderabad&page={i}',
        'https://www.practo.com/search/doctors?results_type=doctor&q=%5B%7B%22word%22%3A%22General%20Physician%22%2C%22autocompleted%22%3Atrue%2C%22category%22%3A%22subspeciality%22%7D%5D&city=Hyderabad&page={i}',
        'https://www.practo.com/search/doctors?results_type=doctor&q=%5B%7B%22word%22%3A%22Dermatologist%22%2C%22autocompleted%22%3Atrue%2C%22category%22%3A%22subspeciality%22%7D%5D&city=Hyderabad&page={i}',
        'https://www.practo.com/search/doctors?results_type=doctor&q=%5B%7B%22word%22%3A%22Ear-nose-throat%20(ent)%20Specialist%22%2C%22autocompleted%22%3Atrue%2C%22category%22%3A%22subspeciality%22%7D%5D&city=Hyderabad&page={i}',
        'https://www.practo.com/search/doctors?results_type=doctor&q=%5B%7B%22word%22%3A%22Gynecologist%2Fobstetrician%22%2C%22autocompleted%22%3Atrue%2C%22category%22%3A%22subspeciality%22%7D%5D&city=Hyderabad&page={i}']

    request_header={'content-type': 'text/plain',
                    'User-Agent': "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/119.0.0.0 Safari/537.36",
                    'Accept-Encoding': 'gzip, deflate, br'}
    for url in URL:
        response = requests.get(url,headers=request_header)
        html_code=response.text
        soup=BeautifulSoup(html_code)
#response = requests.get(URL,headers=request_header)
#html_code = response.text
#soup = BeautifulSoup(html_code)
        containers = soup.find_all('div',attrs={'class':'listing-doctor-card'})
        for container in containers:
            f=container.find('span',attrs={'data-qa-id':'consultation_fee'})
            if f is None:
                Appointment_fee_.append(np.NaN)
            else:
                Appointment_fee_.append(f.text)

# %%
len(Appointment_fee_)
# Out:
# 2380

# %%
df=pd.DataFrame({'DocterName':docter_names,
                'Specialist':specialist_,
                 'Experience':experi,
                 'HospitalName':hosiptal_name,
                'HospitalArea':locality,
                'AppointmentFee':Appointment_fee_,
                'RecommendPercentage':recommendations_,
               'No-Of-Reviews':reviews_})

# %%
df.head()
# Out:
#               DocterName                                     Specialist  \
# 0        Dr. B Varun Rao  Gastroenterologist18 years experience overall
# 1  Dr. Sudarshan Reddy K  Gastroenterologist16 years experience overall
# 2   Dr. Raghuram Kondala  Gastroenterologist18 years experience overall
# 3  Dr. Ramesh Srinivasan  Gastroenterologist27 years experience overall
# 4      Dr. Moka Praneeth  Gastroenterologist14 years experience overall
#
#                     Experience           HospitalName  \
# 0  18 years experience overall    Medicover Hospitals
# 1  16 years experience overall           Tx Hospitals
# 2  18 years experience overall  Continental Hospitals
# 3  27 years experience overall       Apollo Hospitals
# 4  14 years experience overall    Medicover Hospitals
#
#               HospitalArea AppointmentFee RecommendPercentage  \
# 0    Hitech City,Hyderabad           ₹500                91%
# 1          Uppal,Hyderabad           ₹600               100%
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2380 entries, 0 to 2379
# Data columns (total 8 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   DocterName           2380 non-null   object
#  1   Specialist           2380 non-null   object
#  2   Experience           2380 non-null   object
#  3   HospitalName         2380 non-null   object
#  4   HospitalArea         2380 non-null   object
#  5   AppointmentFee       2380 non-null   object
#  6   RecommendPercentage  2300 non-null   object
#  7   No-Of-Reviews        2266 non-null   object
# dtypes: object(8)
# memory usage: 148.9+ KB

# %%
df[df['AppointmentFee']=="₹150"]
# Out:
#                      DocterName                          Specialist  \
# 10    Dr. Chaitanya Kumar Reddy  Dentist26 years experience overall
# 12                   Dr. Preeti  Dentist15 years experience overall
# 80    Dr. Chaitanya Kumar Reddy  Dentist26 years experience overall
# 82                   Dr. Preeti  Dentist15 years experience overall
# 150   Dr. Chaitanya Kumar Reddy  Dentist26 years experience overall
# ...                         ...                                 ...
# 2182                 Dr. Preeti  Dentist15 years experience overall
# 2250             Dr. Anil Kumar  Dentist20 years experience overall
# 2252                 Dr. Preeti  Dentist15 years experience overall
# 2320  Dr. Chaitanya Kumar Reddy  Dentist26 years experience overall
# 2322                 Dr. Preeti  Dentist15 years experience overall
#
#                        Experience                     HospitalName  \
# 10    15 years experience overall                  GC Dental World
# ...

# %%
df.to_csv("practo.csv",index=False)

# %%
docter_names=[]
specialist_=[]
locality=[]
hosiptal_name=[]
Appointment_fee=[]
recommendations_=[]
reviews_=[]

# %%
URL='https://www.practo.com/search/doctors?results_type=doctor&q=%5B%7B%22word%22%3A%22gastroenterologist%22%2C%22autocompleted%22%3Atrue%2C%22category%22%3A%22subspeciality%22%7D%5D&city=Hyderabad&page=2'

# %%
request_header={'content-type': 'text/plain',
                    'User-Agent': "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/119.0.0.0 Safari/537.36",
                    'Accept-Encoding': 'gzip, deflate, br'}

# %%
response = requests.get(URL,headers=request_header)
html_code=response.text
soup=BeautifulSoup(html_code)

# %%
info-section

# %%
containers = soup.find_all('div',attrs={'class':'info-section'})
for container in containers:
    f=container.find('h2',attrs={'data-qa-id':'doctor_name'})
    if f is None:
        docter_names.append(np.NaN)
    else:
        docter_names.append(f.text)
    desgination=container.find('div',attrs={'class':'u-grey_3-text'})
    if desgination is None:
        specialist_.append(np.NaN)
    else:
        specialist_.append(desgination.text)
    places=container.find('div',attrs={'class':'u-bold u-d-inlineblock u-valign--middle'})
    if places is None:
        locality.append(np.NaN)
    else:
        locality.append(places.text)
            
    clinic=container.find('span',attrs={'class':'u-c-pointer u-t-hover-underline'})
    if clinic is None:
        hosiptal_name.append(np.NaN)
    else:
        hosiptal_name.append(clinic.text)
            
    fees=container.find('span',attrs={'data-qa-id':'consultation_fee'})
    if fees is None:
        Appointment_fee.append(np.NaN)
    else:
        Appointment_fee.append(fees.text)
        
    recommend=container.find('span',attrs={'data-qa-id':'doctor_recommendation'})
    if recommend is None:
        recommendations_.append(np.NaN)
    else:
        recommendations_.append(recommend.text)
    review=container.find('span',attrs={'data-qa-id':'total_feedback'})
    if review is None:
        reviews_.append(np.NaN)
    else:
        reviews_.append(review.text)

# %%
docter_names
# Out:
# ['Dr. Suraj Uppalapati',
#  'Dr. Rajendra Prasad Bhupathi',
#  'Dr. Raghavendra Y',
#  'Dr. Sai Krishna Katepally',
#  'Dr. Pavan Reddy T',
#  'Dr. Dheeraj Kumar Anupa',
#  'Dr. Subrahmaneswara Babu',
#  'Dr. N Karunakar Reddy',
#  'Dr. Sivananda Reddy',
#  'Dr. Parag Dashatwar']

# %%
specialist_
# Out:
# ['Gastroenterologist11\xa0years experience overall',
#  'Gastroenterologist23\xa0years experience overall',
#  'Gastroenterologist10\xa0years experience overall',
#  'Gastroenterologist16\xa0years experience overall',
#  'Gastroenterologist11\xa0years experience overall',
#  'Gastroenterologist10\xa0years experience overall',
#  'Gastroenterologist15\xa0years experience overall',
#  'Gastroenterologist19\xa0years experience overall',
#  'Gastroenterologist15\xa0years experience overall',
#  'Gastroenterologist15\xa0years experience overall']

# %%
locality
# Out:
# ['Kondapur,Hyderabad',
#  'LB Nagar,Hyderabad',
#  'Lingampally,Hyderabad',
#  'Habsiguda,Hyderabad',
#  'Gachibowli,Hyderabad',
#  'Ameerpet,Hyderabad',
#  'Secunderabad,Hyderabad',
#  'Nizampet,Hyderabad',
#  'LB Nagar,Hyderabad',
#  'Mehdipatnam,Hyderabad']

# %%
hosiptal_name
# Out:
# ['Gastro 360',
#  'Aware Gleneagles Global Hospitals',
#  'Citizens Speciality Hospitals',
#  'Gastro Care',
#  'Continental Hospitals',
#  'Aster Prime Hospital',
#  'Apollo Hospital',
#  'Matrusri Hospital',
#  'Aware Gleneagles Global Hospitals',
#  'Mythri hospital - Mehdipatnam']

# %%
Appointment_fee
# Out:
# ['₹700',
#  '₹680',
#  '₹800',
#  '₹600',
#  '₹900',
#  '₹900',
#  '₹1500',
#  '₹500',
#  '₹680',
#  '₹650']

# %%
reviews_
# Out:
# ['168\xa0Patient Stories',
#  '3\xa0Patient Stories',
#  '2\xa0Patient Stories',
#  '11\xa0Patient Stories',
#  nan,
#  nan,
#  nan,
#  '8\xa0Patient Stories',
#  '2\xa0Patient Stories',
#  nan]

# %%
recommendations_
# Out:
# ['94% ', '100% ', '67% ', '100% ', nan, nan, nan, '94% ', '100% ', nan]

# %%
docter_name=[]
specialists_=[]
localitys=[]
hosiptal_names=[]
Appointment_fees=[]
recommendation_=[]
review_=[]

# %%
URL='https://www.practo.com/search/doctors?results_type=doctor&q=%5B%7B%22word%22%3A%22gastroenterologist%22%2C%22autocompleted%22%3Atrue%2C%22category%22%3A%22subspeciality%22%7D%5D&city=Hyderabad&page=3'

# %%
request_header={'content-type': 'text/plain',
                    'User-Agent': "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/119.0.0.0 Safari/537.36",
                    'Accept-Encoding': 'gzip, deflate, br'}

# %%
response = requests.get(URL,headers=request_header)
html_code=response.text
soup=BeautifulSoup(html_code)

# %%
containers = soup.find_all('div',attrs={'class':'info-section'})
for container in containers:
    f=container.find('h2',attrs={'data-qa-id':'doctor_name'})
    if f is None:
        docter_name.append(np.NaN)
    else:
        docter_name.append(f.text)
    desgination=container.find('div',attrs={'class':'u-grey_3-text'})
    if desgination is None:
        specialists_.append(np.NaN)
    else:
        specialists_.append(desgination.text)
    places=container.find('div',attrs={'class':'u-bold u-d-inlineblock u-valign--middle'})
    if places is None:
        localitys.append(np.NaN)
    else:
        localitys.append(places.text)
            
    clinic=container.find('span',attrs={'class':'u-c-pointer u-t-hover-underline'})
    if clinic is None:
        hosiptal_names.append(np.NaN)
    else:
        hosiptal_names.append(clinic.text)
            
    fees=container.find('span',attrs={'data-qa-id':'consultation_fee'})
    if fees is None:
        Appointment_fees.append(np.NaN)
    else:
        Appointment_fees.append(fees.text)
        
    recommend=container.find('span',attrs={'data-qa-id':'doctor_recommendation'})
    if recommend is None:
        recommendation_.append(np.NaN)
    else:
        recommendation_.append(recommend.text)
    review=container.find('span',attrs={'data-qa-id':'total_feedback'})
    if review is None:
        review_.append(np.NaN)
    else:
        review_.append(review.text)

# %%
docter_name
# Out:
# ['Dr. Gurunath T Reddy',
#  'Dr. Arshiya Siddiqua',
#  'Dr. V. Pavan Kumar',
#  'Dr. Gabriel Sukumar Chinnam',
#  'Dr. B.V.N. Kumar Sureddi',
#  'Dr. Mudumala Issac Abhilash',
#  'Dr. Prashanth Koyyoda',
#  'Dr. A Bharath Kumar',
#  'Dr. Sundeep Lakhtakia',
#  'Dr. Mohammed Saaduddin azmi']

# %%
specialists_
# Out:
# ['Gastroenterologist32\xa0years experience overall',
#  'Gastroenterologist9\xa0years experience overall',
#  'Gastroenterologist15\xa0years experience overall',
#  'Gastroenterologist33\xa0years experience overall',
#  'Gastroenterologist20\xa0years experience overall',
#  'Gastroenterologist13\xa0years experience overall',
#  'Gastroenterologist13\xa0years experience overall',
#  'Gastroenterologist20\xa0years experience overall',
#  'Gastroenterologist24\xa0years experience overall',
#  'Gastroenterologist14\xa0years experience overall']

# %%
localitys
# Out:
# ['Gachibowli,Hyderabad',
#  'Attapur,Hyderabad',
#  'Nizampet,Hyderabad',
#  'Banjara Hills,Hyderabad',
#  'Nizampet,Hyderabad',
#  'Champapet,Hyderabad',
#  'Jubilee Hills,Hyderabad',
#  'Jubilee Hills,Hyderabad',
#  'Gachibowli,Hyderabad',
#  'Banjara Hills,Hyderabad']

# %%
hosiptal_names
# Out:
# ['Continental Hospitals',
#  'Germanten Hospitals',
#  'SLG Hospitals',
#  'Virinchi Hospitals',
#  'SLG Hospitals',
#  'Sunridge Multispeciality Hospital',
#  'Apollo Hospitals',
#  'Apollo Hospitals',
#  'AIG Hospital',
#  'Tx Hospitals']

# %%
Appointment_fees
# Out:
# ['₹1000',
#  '₹600',
#  '₹700',
#  '₹800',
#  '₹700',
#  '₹700',
#  '₹1000',
#  '₹1200',
#  '₹500',
#  '₹600']

# %%
recommendation_
# Out:
# [nan, nan, nan, '79% ', nan, '98% ', nan, '70% ', '81% ', '100% ']

# %%
review_
# Out:
# [nan,
#  nan,
#  nan,
#  '2\xa0Patient Stories',
#  nan,
#  '77\xa0Patient Stories',
#  nan,
#  '6\xa0Patient Stories',
#  '17\xa0Patient Stories',
#  nan]

# %%
docter_=[]
special_=[]
locality_=[]
hosiptal_=[]
Appointment_=[]
recommend_=[]
reviewss_=[]

# %%
URL='https://www.practo.com/search/doctors?results_type=doctor&q=%5B%7B%22word%22%3A%22gastroenterologist%22%2C%22autocompleted%22%3Atrue%2C%22category%22%3A%22subspeciality%22%7D%5D&city=Hyderabad&page=4'


request_header={'content-type': 'text/plain',
                    'User-Agent': "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/119.0.0.0 Safari/537.36",
                    'Accept-Encoding': 'gzip, deflate, br'}

response = requests.get(URL,headers=request_header)
html_code=response.text
soup=BeautifulSoup(html_code)

# %%
containers = soup.find_all('div',attrs={'class':'info-section'})
for container in containers:
    f=container.find('h2',attrs={'data-qa-id':'doctor_name'})
    if f is None:
        docter_.append(np.NaN)
    else:
        docter_.append(f.text)
    desgination=container.find('div',attrs={'class':'u-grey_3-text'})
    if desgination is None:
        special_.append(np.NaN)
    else:
        special_.append(desgination.text)
    places=container.find('div',attrs={'class':'u-bold u-d-inlineblock u-valign--middle'})
    if places is None:
        locality_.append(np.NaN)
    else:
        locality_.append(places.text)
            
    clinic=container.find('span',attrs={'class':'u-c-pointer u-t-hover-underline'})
    if clinic is None:
        hosiptal_.append(np.NaN)
    else:
        hosiptal_.append(clinic.text)
            
    fees=container.find('span',attrs={'data-qa-id':'consultation_fee'})
    if fees is None:
        Appointment_.append(np.NaN)
    else:
        Appointment_.append(fees.text)
        
    recommend=container.find('span',attrs={'data-qa-id':'doctor_recommendation'})
    if recommend is None:
        recommend_.append(np.NaN)
    else:
        recommend_.append(recommend.text)
    review=container.find('span',attrs={'data-qa-id':'total_feedback'})
    if review is None:
        reviewss_.append(np.NaN)
    else:
        reviewss_.append(review.text)

# %%
docter_
# Out:
# ['Dr. Mohan Ramchandani',
#  'Dr. Pramod Kumar D A',
#  'Dr. Prasad Neelam',
#  'Dr. Shujaath Asif. M',
#  'Dr. Harish',
#  'Dr. Aslambaba D']

# %%
special_
# Out:
# ['Gastroenterologist27\xa0years experience overall',
#  'Gastroenterologist12\xa0years experience overall',
#  'Gastroenterologist13\xa0years experience overall',
#  'Gastroenterologist14\xa0years experience overall',
#  'Gastroenterologist6\xa0years experience overall',
#  'Gastroenterologist12\xa0years experience overall']

# %%
locality_
# Out:
# ['Gachibowli,Hyderabad',
#  'Gachibowli,Hyderabad',
#  'Madhapur,Hyderabad',
#  'Gachibowli,Hyderabad',
#  'Srinagar Colony,Hyderabad',
#  'Champapet,Hyderabad']

# %%
hosiptal_
# Out:
# ['AIG Hospital',
#  'AIG Hospital',
#  'Sravani Hospital',
#  'AIG Hospital',
#  'Gastro Care Clinics',
#  'Sunridge Multispeciality Hospital']

# %%
Appointment_
# Out:
# ['₹500', '₹500', '₹650', '₹500', '₹600', '₹700']

# %%
recommend_
# Out:
# ['71% ', '67% ', '100% ', '25% ', nan, nan]

# %%
reviewss_
# Out:
# ['17\xa0Patient Stories',
#  '3\xa0Patient Stories',
#  '9\xa0Patient Stories',
#  '9\xa0Patient Stories',
#  nan,
#  nan]

# %%
docter_=[]
special_=[]
locality_=[]
hosiptal_=[]
Appointment_=[]
recommend_=[]
reviewss_=[]

# %%
pages=3

for i in range(1,pages):
    URL='https://www.practo.com/search/doctors?results_type=doctor&q=%5B%7B%22word%22%3A%22gastroenterologist%22%2C%22autocompleted%22%3Atrue%2C%22category%22%3A%22subspeciality%22%7D%5D&city=Hyderabad&page={i}'


    request_header={'content-type': 'text/plain',
                    'User-Agent': "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/119.0.0.0 Safari/537.36",
                    'Accept-Encoding': 'gzip, deflate, br'}

    response = requests.get(URL,headers=request_header)
    html_code=response.text
    soup=BeautifulSoup(html_code)
    containers = soup.find_all('div',attrs={'class':'info-section'})
    for container in containers:
        f=container.find('h2',attrs={'data-qa-id':'doctor_name'})
        if f is None:
            docter_.append(np.NaN)
        else:
            docter_.append(f.text)
        desgination=container.find('div',attrs={'class':'u-grey_3-text'})
        if desgination is None:
            special_.append(np.NaN)
        else:
            special_.append(desgination.text)
        places=container.find('div',attrs={'class':'u-bold u-d-inlineblock u-valign--middle'})
        if places is None:
            locality_.append(np.NaN)
        else:
            locality_.append(places.text)
            
        clinic=container.find('span',attrs={'class':'u-c-pointer u-t-hover-underline'})
        if clinic is None:
            hosiptal_.append(np.NaN)
        else:
            hosiptal_.append(clinic.text)
            
        fees=container.find('span',attrs={'data-qa-id':'consultation_fee'})
        if fees is None:
            Appointment_.append(np.NaN)
        else:
            Appointment_.append(fees.text)
        
        recommend=container.find('span',attrs={'data-qa-id':'doctor_recommendation'})
        if recommend is None:
            recommend_.append(np.NaN)
        else:
            recommend_.append(recommend.text)
        review=container.find('span',attrs={'data-qa-id':'total_feedback'})
        if review is None:
            reviewss_.append(np.NaN)
        else:
            reviewss_.append(review.text)

# %%
docter_
# Out:
# ['Dr. B Varun Rao',
#  'Dr. Sudarshan Reddy K',
#  'Dr. Raghuram Kondala',
#  'Dr. Sarada Pasangulapati',
#  'Dr. Ramesh Srinivasan',
#  'Dr. Moka Praneeth',
#  'Dr. B Prabhakar',
#  'Dr. Kiran Peddi',
#  'Dr. Lata Prasad',
#  'Dr. Gopalkrishna',
#  'Dr. B Varun Rao',
#  'Dr. Sudarshan Reddy K',
#  'Dr. Raghuram Kondala',
#  'Dr. Sarada Pasangulapati',
#  'Dr. Ramesh Srinivasan',
#  'Dr. Moka Praneeth',
#  'Dr. B Prabhakar',
#  'Dr. Kiran Peddi',
#  'Dr. Lata Prasad',
#  'Dr. Gopalkrishna',
#  'Dr. B Varun Rao',
#  'Dr. Sudarshan Reddy K',
#  'Dr. Raghuram Kondala',
#  'Dr. Sarada Pasangulapati',
#  'Dr. Ramesh Srinivasan',
#  'Dr. Moka Praneeth',
#  'Dr. B Prabhakar',
#  'Dr. Kiran Peddi',
#  'Dr. Lata Prasad',
#  'Dr. Gopalkrishna']

# %%
import requests
from bs4 import BeautifulSoup
import numpy as np

pages = 
docter_ = []
special_ = []
locality_ = []
hosiptal_ = []
Appointment_ = []
recommend_ = []
reviewss_ = []

for i in range(1, pages):
    URL = f'https://www.practo.com/search/doctors?results_type=doctor&q=%5B%7B%22word%22%3A%22gastroenterologist%22%2C%22autocompleted%22%3Atrue%2C%22category%22%3A%22subspeciality%22%7D%5D&city=Hyderabad&page={i}'

    request_header = {
        'content-type': 'text/plain',
        'User-Agent': "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/119.0.0.0 Safari/537.36",
        'Accept-Encoding': 'gzip, deflate, br'
    }

    response = requests.get(URL, headers=request_header)
    html_code = response.text
    soup = BeautifulSoup(html_code, 'html.parser')
    containers = soup.find_all('div', attrs={'class': 'info-section'})

    for container in containers:
        f = container.find('h2', attrs={'data-qa-id': 'doctor_name'})
        if f is None:
            docter_.append(np.NaN)
        else:
            docter_.append(f.text)

        desgination = container.find('div', attrs={'class': 'u-grey_3-text'})
        if desgination is None:
            special_.append(np.NaN)
        else:
            special_.append(desgination.text)

        places = container.find('div', attrs={'class': 'u-bold u-d-inlineblock u-valign--middle'})
        if places is None:
            locality_.append(np.NaN)
        else:
            locality_.append(places.text)

        clinic = container.find('span', attrs={'class': 'u-c-pointer u-t-hover-underline'})
        if clinic is None:
            hosiptal_.append(np.NaN)
        else:
            hosiptal_.append(clinic.text)

        fees = container.find('span', attrs={'data-qa-id': 'consultation_fee'})
        if fees is None:
            Appointment_.append(np.NaN)
        else:
            Appointment_.append(fees.text)

        recommend = container.find('span', attrs={'data-qa-id': 'doctor_recommendation'})
        if recommend is None:
            recommend_.append(np.NaN)
        else:
            recommend_.append(recommend.text)

        review = container.find('span', attrs={'data-qa-id': 'total_feedback'})
        if review is None:
            reviewss_.append(np.NaN)
        else:
            reviewss_.append(review.text)

# %%
docter_
# Out:
# ['Dr. B Varun Rao',
#  'Dr. Sudarshan Reddy K',
#  'Dr. Raghuram Kondala',
#  'Dr. Sarada Pasangulapati',
#  'Dr. Ramesh Srinivasan',
#  'Dr. Moka Praneeth',
#  'Dr. B Prabhakar',
#  'Dr. Kiran Peddi',
#  'Dr. Lata Prasad',
#  'Dr. Gopalkrishna',
#  'Dr. Suraj Uppalapati',
#  'Dr. Rajendra Prasad Bhupathi',
#  'Dr. Raghavendra Y',
#  'Dr. Sai Krishna Katepally',
#  'Dr. Pavan Reddy T',
#  'Dr. Dheeraj Kumar Anupa',
#  'Dr. Subrahmaneswara Babu',
#  'Dr. N Karunakar Reddy',
#  'Dr. Sivananda Reddy',
#  'Dr. Parag Dashatwar',
#  'Dr. Gurunath T Reddy',
#  'Dr. Arshiya Siddiqua',
#  'Dr. V. Pavan Kumar',
#  'Dr. Gabriel Sukumar Chinnam',
#  'Dr. B.V.N. Kumar Sureddi',
#  'Dr. Mudumala Issac Abhilash',
#  'Dr. Prashanth Koyyoda',
#  'Dr. A Bharath Kumar',
#  'Dr. Sundeep Lakhtakia',
#  'Dr. Mohammed Saaduddin azmi',
#  'Dr. Mohan Ramchandani',
#  'Dr. Pramod Kumar D A',
#  'Dr. Prasad Neelam',
#  'Dr. Shujaath Asif. M',
#  'Dr. Harish',
#  'Dr. Aslambaba D']

# %%
import requests
from bs4 import BeautifulSoup
import numpy as np

pages = 25
docter_ = []
special_ = []
locality_ = []
hosiptal_ = []
Appointment_ = []
recommend_ = []
reviewss_ = []

for i in range(1, pages):
    URL = f'https://www.practo.com/search/doctors?results_type=doctor&q=%5B%7B%22word%22%3A%22gastroenterologist%22%2C%22autocompleted%22%3Atrue%2C%22category%22%3A%22subspeciality%22%7D%5D&city=Hyderabad&page={i}'

    request_header = {
        'content-type': 'text/plain',
        'User-Agent': "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/119.0.0.0 Safari/537.36",
        'Accept-Encoding': 'gzip, deflate, br'
    }

    response = requests.get(URL, headers=request_header)
    html_code = response.text
    soup = BeautifulSoup(html_code, 'html.parser')
    containers = soup.find_all('div', attrs={'class': 'info-section'})

    for container in containers:
        f = container.find('h2', attrs={'data-qa-id': 'doctor_name'})
        if f is None:
            docter_.append(np.NaN)
        else:
            docter_.append(f.text)

        desgination = container.find('div', attrs={'class': 'u-grey_3-text'})
        if desgination is None:
            special_.append(np.NaN)
        else:
            special_.append(desgination.text)

        places = container.find('div', attrs={'class': 'u-bold u-d-inlineblock u-valign--middle'})
        if places is None:
            locality_.append(np.NaN)
        else:
            locality_.append(places.text)

        clinic = container.find('span', attrs={'class': 'u-c-pointer u-t-hover-underline'})
        if clinic is None:
            hosiptal_.append(np.NaN)
        else:
            hosiptal_.append(clinic.text)

        fees = container.find('span', attrs={'data-qa-id': 'consultation_fee'})
        if fees is None:
            Appointment_.append(np.NaN)
        else:
            Appointment_.append(fees.text)

        recommend = container.find('span', attrs={'data-qa-id': 'doctor_recommendation'})
        if recommend is None:
            recommend_.append(np.NaN)
        else:
            recommend_.append(recommend.text)

        review = container.find('span', attrs={'data-qa-id': 'total_feedback'})
        if review is None:
            reviewss_.append(np.NaN)
        else:
            reviewss_.append(review.text)

# %% [markdown]
# # Final code free from duplicates

# %%
import requests
from bs4 import BeautifulSoup
import numpy as np

# Define the list of URLs
urls = [
    'https://www.practo.com/search/doctors?results_type=doctor&q=%5B%7B%22word%22%3A%22gastroenterologist%22%2C%22autocompleted%22%3Atrue%2C%22category%22%3A%22subspeciality%22%7D%5D&city=hyderabad',
    'https://www.practo.com/search/doctors?results_type=doctor&q=%5B%7B%22word%22%3A%22dentist%22%2C%22autocompleted%22%3Atrue%2C%22category%22%3A%22subspeciality%22%7D%5D&city=hyderabad',
    'https://www.practo.com/search/doctors?results_type=doctor&q=%5B%7B%22word%22%3A%22general%20physician%22%2C%22autocompleted%22%3Atrue%2C%22category%22%3A%22subspeciality%22%7D%5D&city=hyderabad',
    'https://www.practo.com/search/doctors?results_type=doctor&q=%5B%7B%22word%22%3A%22dermatologist%22%2C%22autocompleted%22%3Atrue%2C%22category%22%3A%22subspeciality%22%7D%5D&city=hyderabad',
    'https://www.practo.com/search/doctors?results_type=doctor&q=%5B%7B%22word%22%3A%22gynecologist%22%2C%22autocompleted%22%3Atrue%2C%22category%22%3A%22subspeciality%22%7D%5D&city=hyderabad',
    'https://www.practo.com/search/doctors?results_type=doctor&q=%5B%7B%22word%22%3A%22cardiologist%22%2C%22autocompleted%22%3Atrue%2C%22category%22%3A%22subspeciality%22%7D%5D&city=hyderabad',
    'https://www.practo.com/search/doctors?results_type=doctor&q=%5B%7B%22word%22%3A%22orthopedician%22%2C%22autocompleted%22%3Atrue%2C%22category%22%3A%22common_name%22%7D%5D&city=hyderabad',
    'https://www.practo.com/search/doctors?results_type=doctor&q=%5B%7B%22word%22%3A%22neurologist%22%2C%22autocompleted%22%3Atrue%2C%22category%22%3A%22subspeciality%22%7D%5D&city=hyderabad',
    'https://www.practo.com/search/doctors?results_type=doctor&q=%5B%7B%22word%22%3A%22pulmonologist%22%2C%22autocompleted%22%3Atrue%2C%22category%22%3A%22subspeciality%22%7D%5D&city=hyderabad'
]

# Initialize lists to store data
docter_ = []
special_ = []
locality_ = []
hosiptal_ = []
Appointment_ = []
recommend_ = []
reviewss_ = []
experi=[]
request_header = {
    'content-type': 'text/plain',
    'User-Agent': "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/119.0.0.0 Safari/537.36",
    'Accept-Encoding': 'gzip, deflate, br'
}

# Iterate over each URL
for url in urls:
    for i in range(1, 20):  # Adjust the range based on the total number of pages
        page_url = f'{url}&page={i}'
        response = requests.get(page_url, headers=request_header)

        # Check if the request was successful
        if response.ok:
            html_code = response.text
            soup = BeautifulSoup(html_code, 'html.parser')

            # Now you can proceed with parsing the HTML
            containers = soup.find_all('div', attrs={'class': 'listing-doctor-card'})

            for container in containers:
                f = container.find('h2', attrs={'data-qa-id': 'doctor_name'})
                if f is None:
                    docter_.append(np.NaN)
                else:
                    docter_.append(f.text)

                desgination = container.find('div', attrs={'class': 'u-grey_3-text'})
                if desgination is None:
                    special_.append(np.NaN)
                else:
                    special_.append(desgination.text)

                places = container.find('div', attrs={'class': 'u-bold u-d-inlineblock u-valign--middle'})
                if places is None:
                    locality_.append(np.NaN)
                else:
                    locality_.append(places.text)

                clinic = container.find('span', attrs={'class': 'u-c-pointer u-t-hover-underline'})
                if clinic is None:
                    hosiptal_.append(np.NaN)
                else:
                    hosiptal_.append(clinic.text)

                fees = container.find('span', attrs={'data-qa-id': 'consultation_fee'})
                if fees is None:
                    Appointment_.append(np.NaN)
                else:
                    Appointment_.append(fees.text)

                recommend = container.find('span', attrs={'data-qa-id': 'doctor_recommendation'})
                if recommend is None:
                    recommend_.append(np.NaN)
                else:
                    recommend_.append(recommend.text)

                review = container.find('span', attrs={'data-qa-id': 'total_feedback'})
                if review is None:
                    reviewss_.append(np.NaN)
                else:
                    reviewss_.append(review.text)
                experience=container.find('div',attrs={'class':'uv2-spacer--xs-top'})
                if experience is None:
                    experi.append(np.NaN)
                else:
                    experi.append(experience.text)

                

        else:
            print(f"Failed to fetch data from {page_url}. Status code: {response.status_code}")

# Now you can use the Appointment_fee_ list as needed

# %%
special_
# Out:
# ['Gastroenterologist18\xa0years experience overall',
#  'Gastroenterologist16\xa0years experience overall',
#  'Gastroenterologist18\xa0years experience overall',
#  'Gastroenterologist15\xa0years experience overall',
#  'Gastroenterologist27\xa0years experience overall',
#  'Gastroenterologist14\xa0years experience overall',
#  'Gastroenterologist28\xa0years experience overall',
#  'Gastroenterologist27\xa0years experience overall',
#  'Gastroenterologist23\xa0years experience overall',
#  'Gastroenterologist16\xa0years experience overall',
#  'Gastroenterologist11\xa0years experience overall',
#  'Gastroenterologist23\xa0years experience overall',
#  'Gastroenterologist10\xa0years experience overall',
#  'Gastroenterologist16\xa0years experience overall',
#  'Gastroenterologist11\xa0years experience overall',
#  'Gastroenterologist10\xa0years experience overall',
#  'Gastroenterologist15\xa0years experience overall',
#  'Gastroenterologist19\xa0years experience overall',
# ...

# %%
experience=container.find('div',attrs={'class':'uv2-spacer--xs-top'})
            if experience is None:
                experi.append(np.NaN)
            else:
                experi.append(experience.text)

# %%
docter_
# Out:
# ['Dr. B Varun Rao',
#  'Dr. Sudarshan Reddy K',
#  'Dr. Raghuram Kondala',
#  'Dr. Sarada Pasangulapati',
#  'Dr. Ramesh Srinivasan',
#  'Dr. Moka Praneeth',
#  'Dr. B Prabhakar',
#  'Dr. Kiran Peddi',
#  'Dr. Lata Prasad',
#  'Dr. Gopalkrishna',
#  'Dr. Suraj Uppalapati',
#  'Dr. Rajendra Prasad Bhupathi',
#  'Dr. Raghavendra Y',
#  'Dr. Sai Krishna Katepally',
#  'Dr. Pavan Reddy T',
#  'Dr. Dheeraj Kumar Anupa',
#  'Dr. Subrahmaneswara Babu',
#  'Dr. N Karunakar Reddy',
#  'Dr. Sivananda Reddy',
#  'Dr. Parag Dashatwar',
#  'Dr. Gurunath T Reddy',
#  'Dr. Arshiya Siddiqua',
#  'Dr. V. Pavan Kumar',
#  'Dr. Gabriel Sukumar Chinnam',
#  'Dr. B.V.N. Kumar Sureddi',
#  'Dr. Mudumala Issac Abhilash',
#  'Dr. Prashanth Koyyoda',
#  'Dr. A Bharath Kumar',
#  'Dr. Sundeep Lakhtakia',
#  'Dr. Mohammed Saaduddin azmi',
#  'Dr. Mohan Ramchandani',
#  'Dr. Pramod Kumar D A',
#  'Dr. Prasad Neelam',
#  'Dr. Shujaath Asif. M',
#  'Dr. Harish',
#  'Dr. Aslambaba D',
#  'Dr. Preeti',
# ...

# %%
spec

# %%
import pandas as pd

# %%
docter_ = []
special_ = []
locality_ = []
hosiptal_ = []
Appointment_ = []
recommend_ = []
reviewss_ = []

# %%
df=pd.DataFrame({'DocterName':docter_,
                'Specialist':special_,
                'Experience(in years)':experi,
                'HospitalName':hosiptal_,
                'HospitalArea':locality_,
                'AppointmentFee':Appointment_,
                'RecommendPercentage':recommend_,
                'NoOfReviews':reviewss_})

# %%
hosiptal_
# Out:
# ['Medicover Hospitals',
#  'Tx Hospitals',
#  'Continental Hospitals',
#  'Gastro Care Clinics',
#  'Apollo Hospitals',
#  'Medicover Hospitals',
#  'Apollo Hospital',
#  'Gastro Care Clinics',
#  'Virinchi Hospitals',
#  'Gastro Care Liver Pancreas And Endoscopic Clinic',
#  'Gastro 360',
#  'Aware Gleneagles Global Hospitals',
#  'Citizens Speciality Hospitals',
#  'Gastro Care',
#  'Continental Hospitals',
#  'Aster Prime Hospital',
#  'Apollo Hospital',
#  'Matrusri Hospital',
#  'Aware Gleneagles Global Hospitals',
#  'Mythri hospital - Mehdipatnam',
#  'Continental Hospitals',
#  'Germanten Hospitals',
#  'SLG Hospitals',
#  'Virinchi Hospitals',
#  'SLG Hospitals',
#  'Sunridge Multispeciality Hospital',
#  'Apollo Hospitals',
#  'Apollo Hospitals',
#  'AIG Hospital',
#  'Tx Hospitals',
#  'AIG Hospital',
#  'AIG Hospital',
#  'Sravani Hospital',
#  'AIG Hospital',
#  'Gastro Care Clinics',
#  'Sunridge Multispeciality Hospital',
#  'Elysian  Aesthetics Dental Care',
# ...

# %%
import requests
from bs4 import BeautifulSoup
import numpy as np

# Define the list of URLs
urls = [
    'https://www.practo.com/search/doctors?results_type=doctor&q=%5B%7B%22word%22%3A%22gastroenterologist%22%2C%22autocompleted%22%3Atrue%2C%22category%22%3A%22subspeciality%22%7D%5D&city=hyderabad',
    'https://www.practo.com/search/doctors?results_type=doctor&q=%5B%7B%22word%22%3A%22dentist%22%2C%22autocompleted%22%3Atrue%2C%22category%22%3A%22subspeciality%22%7D%5D&city=hyderabad',
    'https://www.practo.com/search/doctors?results_type=doctor&q=%5B%7B%22word%22%3A%22general%20physician%22%2C%22autocompleted%22%3Atrue%2C%22category%22%3A%22subspeciality%22%7D%5D&city=hyderabad',
    'https://www.practo.com/search/doctors?results_type=doctor&q=%5B%7B%22word%22%3A%22dermatologist%22%2C%22autocompleted%22%3Atrue%2C%22category%22%3A%22subspeciality%22%7D%5D&city=hyderabad',
    'https://www.practo.com/search/doctors?results_type=doctor&q=%5B%7B%22word%22%3A%22gynecologist%22%2C%22autocompleted%22%3Atrue%2C%22category%22%3A%22subspeciality%22%7D%5D&city=hyderabad',
    'https://www.practo.com/search/doctors?results_type=doctor&q=%5B%7B%22word%22%3A%22cardiologist%22%2C%22autocompleted%22%3Atrue%2C%22category%22%3A%22subspeciality%22%7D%5D&city=hyderabad',
    'https://www.practo.com/search/doctors?results_type=doctor&q=%5B%7B%22word%22%3A%22orthopedician%22%2C%22autocompleted%22%3Atrue%2C%22category%22%3A%22common_name%22%7D%5D&city=hyderabad',
    'https://www.practo.com/search/doctors?results_type=doctor&q=%5B%7B%22word%22%3A%22neurologist%22%2C%22autocompleted%22%3Atrue%2C%22category%22%3A%22subspeciality%22%7D%5D&city=hyderabad',
    'https://www.practo.com/search/doctors?results_type=doctor&q=%5B%7B%22word%22%3A%22pulmonologist%22%2C%22autocompleted%22%3Atrue%2C%22category%22%3A%22subspeciality%22%7D%5D&city=hyderabad'
]

# Initialize lists to store data
experi = []

request_header = {
    'content-type': 'text/plain',
    'User-Agent': "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/119.0.0.0 Safari/537.36",
    'Accept-Encoding': 'gzip, deflate, br'
}

# Iterate over each URL
for url in urls:
    for i in range(1, 15):  # Adjust the range based on the total number of pages
        page_url = f'{url}&page={i}'
        response = requests.get(page_url, headers=request_header)

        # Check if the request was successful
        if response.ok:
            html_code = response.text
            soup = BeautifulSoup(html_code, 'html.parser')

            # Now you can proceed with parsing the HTML
            containers = soup.find_all('div', attrs={'class': 'listing-doctor-card'})

            for container in containers:
                experience=container.find('div',attrs={'class':'uv2-spacer--xs-top'})
                if experience is None:
                    experi.append(np.NaN)
                else:
                    experi.append(experience.text)
        else:
            print(f"Failed to fetch data from {page_url}. Status code: {response.status_code}")

# Now you can use the Appointment_fee_ list as needed

# %%
experi
# Out:
# ['18\xa0years experience overall',
#  '16\xa0years experience overall',
#  '18\xa0years experience overall',
#  '15\xa0years experience overall',
#  '27\xa0years experience overall',
#  '14\xa0years experience overall',
#  '28\xa0years experience overall',
#  '27\xa0years experience overall',
#  '23\xa0years experience overall',
#  '16\xa0years experience overall',
#  '11\xa0years experience overall',
#  '23\xa0years experience overall',
#  '10\xa0years experience overall',
#  '16\xa0years experience overall',
#  '11\xa0years experience overall',
#  '10\xa0years experience overall',
#  '15\xa0years experience overall',
#  '19\xa0years experience overall',
#  '15\xa0years experience overall',
#  '15\xa0years experience overall',
#  '32\xa0years experience overall',
#  '9\xa0years experience overall',
#  '15\xa0years experience overall',
#  '33\xa0years experience overall',
#  '20\xa0years experience overall',
#  '13\xa0years experience overall',
#  '13\xa0years experience overall',
# ...

# %%
df.head()
# Out:
#                  DocterName                                     Specialist  \
# 0           Dr. B Varun Rao  Gastroenterologist18 years experience overall
# 1     Dr. Sudarshan Reddy K  Gastroenterologist16 years experience overall
# 2      Dr. Raghuram Kondala  Gastroenterologist18 years experience overall
# 3  Dr. Sarada Pasangulapati  Gastroenterologist15 years experience overall
# 4     Dr. Ramesh Srinivasan  Gastroenterologist27 years experience overall
#
#           Experience(in years)           HospitalName  \
# 0  18 years experience overall    Medicover Hospitals
# 1  16 years experience overall           Tx Hospitals
# 2  18 years experience overall  Continental Hospitals
# 3  15 years experience overall    Gastro Care Clinics
# 4  27 years experience overall       Apollo Hospitals
#
#               HospitalArea AppointmentFee RecommendPercentage  \
# 0    Hitech City,Hyderabad           ₹500                91%
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1055 entries, 0 to 1054
# Data columns (total 8 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   DocterName            1055 non-null   object
#  1   Specialist            1055 non-null   object
#  2   Experience(in years)  1055 non-null   object
#  3   HospitalName          1055 non-null   object
#  4   HospitalArea          1055 non-null   object
#  5   AppointmentFee        1055 non-null   object
#  6   RecommendPercentage   857 non-null    object
#  7   NoOfReviews           819 non-null    object
# dtypes: object(8)
# memory usage: 66.1+ KB

# %%
df.to_csv("freedups.csv",index=False)
